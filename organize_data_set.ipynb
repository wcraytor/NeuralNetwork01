# %%
# organize_dataset.py
import os
import shutil
import numpy as np
from pathlib import Path

# terminal commands:
# Count only files (ignore subfolders):  find . -maxdepth 1 -type f | wc -l
# Count only folders:  find . -maxdepth 1 -type d | wc -l
# Count files recursively:   find . -maxdepth 1 -type d | wc -l
# Count all items in folder:  ls -1 | wc -l

orig_dir = Path("images/CatDog")
raw_dir = Path('images/raw/train')
train_cat = Path('images/train/cat')
#print("train_cat:" + str(train_cat))
train_non_cat = Path('images/train/non_cat')
val_cat = Path('images/val/cat')
val_non_cat = Path('images/val/non_cat')
test_cat = Path('images/test/cat')
test_non_cat = Path('images/test/non_cat')

# %%
for d in [train_cat, train_non_cat, val_cat, val_non_cat, test_cat, test_non_cat]:
    d.mkdir(parents=True, exist_ok=True)

for filename in os.listdir(orig_dir):
    src_file = os.path.join(orig_dir, filename)
    dst_file = os.path.join(raw_dir, filename)

    if os.path.isfile(src_file):   # only move files, not subfolders
        shutil.move(src_file, dst_file)

overall_pct = 0.20
train_ratio, val_ratio, test_ratio = 0.7*overall_pct, 0.15*overall_pct, 0.15*overall_pct
print("train_ratio:" + str(train_ratio))
print("val_ration:" + str(val_ratio))
print("test_ratio:" + str(test_ratio))

cat_files = list(raw_dir.glob('cat.*.jpg'))

print("cat files:" + str(cat_files))
np.random.shuffle(cat_files)
n_cat = len(cat_files)
print("n_cat:" + str(n_cat))

n_train = int(n_cat * train_ratio)
print("train_ration:" + str(train_ratio))

n_val = int(n_cat * val_ratio)
print("n_train:" + str(n_train))

n_val = int(n_cat * val_ratio)

for i, img in enumerate(cat_files):
    if i < n_train:
        shutil.move(img, train_cat / img.name)
    elif i < n_train + n_val:
        shutil.move(img, val_cat / img.name)
    else:
        shutil.move(img, test_cat / img.name)

dog_files = list(raw_dir.glob('dog.*.jpg'))
np.random.shuffle(dog_files)
n_dog = len(dog_files)
n_train = int(n_dog * train_ratio)
n_val = int(n_dog * val_ratio)

for i, img in enumerate(dog_files):
    if i < n_train:
        shutil.move(img, train_non_cat / img.name)
    elif i < n_train + n_val:
        shutil.move(img, val_non_cat / img.name)
    else:
        shutil.move(img, test_non_cat / img.name)

print(f"Moved {n_cat} cat images: {n_train} train, {n_val} val, {n_cat - n_train - n_val} test")
print(f"Moved {n_dog} dog images: {n_train} train, {n_val} val, {n_dog - n_train - n_val} test")
# Out:
# train_ratio:0.13999999999999999
# val_ration:0.03
# test_ratio:0.03
# cat files:[PosixPath('images/raw/train/cat.5077.jpg'), PosixPath('images/raw/train/cat.2718.jpg'), PosixPath('images/raw/train/cat.10151.jpg'), PosixPath('images/raw/train/cat.3406.jpg'), PosixPath('images/raw/train/cat.4369.jpg'), PosixPath('images/raw/train/cat.7660.jpg'), PosixPath('images/raw/train/cat.8553.jpg'), PosixPath('images/raw/train/cat.9895.jpg'), PosixPath('images/raw/train/cat.1211.jpg'), PosixPath('images/raw/train/cat.6218.jpg'), PosixPath('images/raw/train/cat.1577.jpg'), PosixPath('images/raw/train/cat.12020.jpg'), PosixPath('images/raw/train/cat.7106.jpg'), PosixPath('images/raw/train/cat.8235.jpg'), PosixPath('images/raw/train/cat.952.jpg'), PosixPath('images/raw/train/cat.3360.jpg'), PosixPath('images/raw/train/cat.11529.jpg'), PosixPath('images/raw/train/cat.10637.jpg'), PosixPath('images/raw/train/cat.5711.jpg'), PosixPath('images/raw/train/cat.946.jpg'), PosixPath('images/raw/train/cat.3374.jpg'), PosixPath('images/raw/train/cat.10623.jpg'), PosixPath('images/raw/train/cat.5705.jpg'), PosixPath('images/raw/train/cat.1563.jpg'), PosixPath('images/raw/train/cat.12034.jpg'), PosixPath('images/raw/train/cat.7112.jpg'), PosixPath('images/raw/train/cat.8221.jpg'), PosixPath('images/raw/train/cat.7674.jpg'), PosixPath('images/raw/train/cat.8547.jpg'), PosixPath('images/raw/train/cat.9881.jpg'), PosixPath('images/raw/train/cat.1205.jpg'), PosixPath('images/raw/train/cat.9659.jpg'), PosixPath('images/raw/train/cat.5063.jpg'), PosixPath('images/raw/train/cat.10145.jpg'), PosixPath('images/raw/train/cat.3412.jpg'), PosixPath('images/raw/train/cat.7884.jpg'), PosixPath('images/raw/train/cat.9671.jpg'), PosixPath('images/raw/train/cat.6542.jpg'), PosixPath('images/raw/train/cat.2724.jpg'), PosixPath('images/raw/train/cat.11273.jpg'), PosixPath('images/raw/train/cat.4355.jpg'), PosixPath('images/raw/train/cat.4433.jpg'), PosixPath('images/raw/train/cat.11515.jpg'), PosixPath('images/raw/train/cat.2042.jpg'), PosixPath('images/raw/train/cat.9117.jpg'), PosixPath('images/raw/train/cat.6224.jpg'), PosixPath('images/raw/train/cat.8209.jpg'), PosixPath('images/raw/train/cat.9103.jpg'), PosixPath('images/raw/train/cat.6230.jpg'), PosixPath('images/raw/train/cat.12008.jpg'), PosixPath('images/raw/train/cat.4427.jpg'), PosixPath('images/raw/train/cat.11501.jpg'), PosixPath('images/raw/train/cat.3348.jpg'), PosixPath('images/raw/train/cat.2056.jpg'), PosixPath('images/raw/train/cat.5739.jpg'), PosixPath('images/raw/train/cat.10179.jpg'), PosixPath('images/raw/train/cat.2730.jpg'), PosixPath('images/raw/train/cat.11267.jpg'), PosixPath('images/raw/train/cat.4341.jpg'), PosixPath('images/raw/train/cat.7648.jpg'), PosixPath('images/raw/train/cat.1239.jpg'), PosixPath('images/raw/train/cat.7890.jpg'), PosixPath('images/raw/train/cat.9665.jpg'), PosixPath('images/raw/train/cat.6556.jpg'), PosixPath('images/raw/train/cat.6.jpg'), PosixPath('images/raw/train/cat.8590.jpg'), PosixPath('images/raw/train/cat.9856.jpg'), PosixPath('images/raw/train/cat.2903.jpg'), PosixPath('images/raw/train/cat.10192.jpg'), PosixPath('images/raw/train/cat.749.jpg'), PosixPath('images/raw/train/cat.991.jpg'), PosixPath('images/raw/train/cat.985.jpg'), PosixPath('images/raw/train/cat.10838.jpg'), PosixPath('images/raw/train/cat.11298.jpg'), PosixPath('images/raw/train/cat.2917.jpg'), PosixPath('images/raw/train/cat.10186.jpg'), PosixPath('images/raw/train/cat.8584.jpg'), PosixPath('images/raw/train/cat.9842.jpg'), PosixPath('images/raw/train/cat.4396.jpg'), PosixPath('images/raw/train/cat.5088.jpg'), PosixPath('images/raw/train/cat.7847.jpg'), PosixPath('images/raw/train/cat.6581.jpg'), PosixPath('images/raw/train/cat.1588.jpg'), PosixPath('images/raw/train/cat.2081.jpg'), PosixPath('images/raw/train/cat.775.jpg'), PosixPath('images/raw/train/cat.10810.jpg'), PosixPath('images/raw/train/cat.5936.jpg'), PosixPath('images/raw/train/cat.761.jpg'), PosixPath('images/raw/train/cat.2095.jpg'), PosixPath('images/raw/train/cat.10804.jpg'), PosixPath('images/ra ...
# n_cat:12490
# train_ration:0.13999999999999999
# n_train:1748
# Moved 12490 cat images: 1745 train, 374 val, 10371 test
# Moved 12469 dog images: 1745 train, 374 val, 10350 test
